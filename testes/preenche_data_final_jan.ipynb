# %%
# %pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd
import socket

# %%
# %run "funcoes_analise_arquivo_final.ipynb"

# %%
# Carre
dados_webservice = pd.read_csv('../arquivos/arquivo_final.csv')
dados_webservice.sort_values(by='DateTimeRead', ascending=False)
print(dados_webservice)
# Out:
#        EnterpriseName  PrinterDeviceID BrandName            PrinterModelName  \
# 0         9853_TRE_BA              268        HP         LaserJet MFP E52645
# 1         9853_TRE_BA              268        HP         LaserJet MFP E52645
# 2         9853_TRE_BA              268        HP         LaserJet MFP E52645
# 3         9853_TRE_BA              268        HP         LaserJet MFP E52645
# 4         9853_TRE_BA              268        HP         LaserJet MFP E52645
# ...               ...              ...       ...                         ...
# 256948    9853_TRE_BA              654        HP  Color LaserJet Flow E87760
# 256949    9853_TRE_BA              654        HP  Color LaserJet Flow E87760
# 256950    9853_TRE_BA              654        HP  Color LaserJet Flow E87760
# 256951    9853_TRE_BA              656        HP         LaserJet MFP E52645
# 256952    9853_TRE_BA              656        HP         LaserJet MFP E52645
#
# ...

# %%
dados_janeiro = pd.read_csv('../data/data_jan_final.csv')
# Out:
# Index(['SerialNumber', 'EnterpriseName', 'PrinterDeviceID', 'BrandName',
#        'PrinterModelName', 'AddressName', 'DateTimeRead', 'ReferenceMono',
#        'ReferenceColor', 'Engaged', 'RealDataCapture'],
#       dtype='object')

# %%
# todos os valores do dia 01/01/2024 que estão vazios
df_filtrado = dados_janeiro[pd.isna(dados_janeiro['DateTimeRead'])]

# %%
# Iterar sobre a data base de janeiro
for _, rows in df_filtrado.iterrows():
    SerialNumber = rows['SerialNumber']
    DateTimeRead = rows['DateTimeRead']
    ReferenceMono = rows['ReferenceMono']
    ReferenceColor = rows['ReferenceColor']
    RealDataCapture = rows['RealDataCapture']

    indice = 0
    while indice < len(df_filtrado)
        for _, rows2 in dados_webservice.iterrows():
            if rows2['SerialNumber'] == SerialNumber:
            print(rows2['SerialNumber'])

    
    # procurar no arquivo_final.csv a impressora de mesmo serial que tem os dados mais recentes e preencher o dado vazio
# Out:
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# BRBSN8RJMX
# ...
